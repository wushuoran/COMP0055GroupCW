# %%
import pandas as pd
import numpy as np
import flip_data
import gd_poisoner

# %%
poi_train_x = pd.read_csv('train_X.csv')
poi_train_x = np.matrix(poi_train_x.to_numpy())
poi_train_y = pd.read_csv('train_y.csv')
poi_train_y = poi_train_y['Life Expectancy'].tolist()
poi_test_x = pd.read_csv('test_X.csv')
poi_test_x = np.matrix(poi_test_x.to_numpy())
poi_test_y = pd.read_csv('test_y.csv')
poi_test_y = poi_test_y['Life Expectancy'].tolist()
poi_val_x = pd.read_csv('val_X.csv')
poi_val_x = np.matrix(poi_val_x.to_numpy())
poi_val_y = pd.read_csv('val_y.csv')
poi_val_y = poi_val_y['Life Expectancy'].tolist()

# num of max poisoning points, max 20% poison rate
poison_ct = 328
# num of points to train model
train_ct = len(poi_train_x)
test_ct = len(poi_test_x)
# proportion of poisoning
total_prop = poison_ct / (poison_ct + train_ct)
print ("Posion count: ", poison_ct, " Train count: ", train_ct, " Test count: ", test_ct, " Proportion of poisoning: ", total_prop)
# Out:
# Posion count:  328  Train count:  1319  Test count:  165  Proportion of poisoning:  0.19914996964177292

# %% [markdown]
# # Inverse Flip & Elastic Network Poisoner

# %%
# define parameters for poisoner
eta = 0.01 # gradient descent step size (note gradients are normalized)
beta = 0.05 # decay rate for line search
sigma = 0.9 # line search stop condition
epsilon = 1e-4 # poisoning stop condition
stop1 = 3
stop2 = 10
stop3 = 5
decrease_rate = 0.85

# flip the data
x_flip, y_flip = flip_data.flip_data.inverse_flip(poi_train_x,poi_train_y,poison_ct)

poiser = gd_poisoner.e_net_poisoner(poi_train_x, poi_train_y, poi_test_x, poi_test_y, poi_val_x, poi_val_y, eta, beta, sigma, epsilon)
classifier, lam = poiser.learn_model(np.concatenate((poi_train_x, x_flip), axis=0), poi_train_y + y_flip, None)
print("classifier: ", classifier)
err = poiser.compute_error(classifier,False,False)[0]
x_flip = np.matrix(x_flip)
y_flip = y_flip[:]
"""
Evaluate the poisoning attack with the poison rate of 4%, 8%, 12%, 16%, 20%
"""
for i in  range(5):
    # calculate the amt of data that should be poisoned in this iteration
    current_prop = 0.2*(i + 1)*total_prop
    sample_amt = int(train_ct*(current_prop/(1 - current_prop)))
    current_x_pois = x_flip[:sample_amt,:]
    current_y_pois = y_flip[:sample_amt]
    # poison data
    x_pois_result, y_pois_result = poiser.poison_data(current_x_pois, current_y_pois,stop1, stop2, stop3, decrease_rate)
    x_poised = np.concatenate((poi_train_x,x_pois_result),axis = 0)
    y_poised = poi_train_y + y_pois_result
    # train the model on poisoned data
    classifier_poised, lam = poiser.learn_model(x_poised,y_poised,None)
    print("Poisoned classifier: ", classifier_poised, ", \nReturned lambda: ", lam)
    classifier = poiser.init_classifier
    if i != 4:
        err_unpoised = poiser.compute_error(classifier,False,False)
        err = poiser.compute_error(classifier_poised,False,False)
        print("\nPoison Proportion: ", round(current_prop*100,2),"%")
    else:
        err_unpoised = poiser.compute_error(classifier,True,False)
        err = poiser.compute_error(classifier_poised,True,True)
        print("\nPoison Proportion: ", round(total_prop*100,2), "%. Max reached, terminate")
    print("\nAfter Flipping, Unpoisoned \n Validation MSE: ", err_unpoised[0], "\n Test MSE:", err_unpoised[1])
    print("\nAfter Flipping & Poisoning:\n Validation MSE: ", err[0], "\n Test MSE:", err[1])
# Out:
# classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True)
#
#
# *****************************
# **** Poison Count:  54  ****
# *****************************
# Iteration  0
# Objective Value:  0.0066797602768377895  Change:  0.0066797602768377895
# Validation MSE  0.0049932643835703385
# Test MSE  0.006916265388776628
#
# Iteration  1
# Objective Value: 0.004980193731132113  Difference:  -0.0016995665457056764
# NO PROGRESS MADE!
#
# Iteration  2
# Objective Value: 0.004980214270909119  Difference:  -0.0016995460059286704
# NO PROGRESS MADE!
#
# Iteration  3
# Objective Value: 0.0049802321261188985  Difference:  -0.001699528150718891
# NO PROGRESS MADE!
#
# Iteration  4
# Objective Value: 0.0049802473481431984  Difference:  -0.001699512928694591
# NO PROGRESS MADE!
#
# Iteration  5
# Objective Value: 0.004980260350570625  Difference:  -0.0016994999262671647
# NO PROGRESS MADE!
#
# Poisoned classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True) ,
# Returned lambda:  7.432486579840555e-05
#
# Poison Proportion:  3.98 %
#
# After Flipping, Unpoisoned
#  Validation MSE:  0.0037623749723120934
#  Test MSE: 0.0047619349297774605
#
# After Flipping & Poisoning:
#  Validation MSE:  0.0049932643835703385
#  Test MSE: 0.006916265388776628
#
#
# *****************************
# **** Poison Count:  114  ****
# *****************************
# Iteration  0
# Objective Value:  0.010878902749699758  Change:  0.010878902749699758
# Validation MSE  0.00868911953716346
# Test MSE  0.011638771117738988
#
# Iteration  1
# Objective Value: 0.0051022503648998265  Difference:  -0.005776652384799932
# NO PROGRESS MADE!
#
# Iteration  2
# Objective Value: 0.005102286083839517  Difference:  -0.005776616665860241
# NO PROGRESS MADE!
#
# Iteration  3
# Objective Value: 0.005102316326196286  Difference:  -0.005776586423503472
# NO PROGRESS MADE!
#
# Iteration  4
# Objective Value: 0.005102341303768579  Difference:  -0.0057765614459311795
# NO PROGRESS MADE!
#
# Iteration  5
# Objective Value: 0.005102362164815772  Difference:  -0.005776540584883986
# NO PROGRESS MADE!
#
# Poisoned classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True) ,
# Returned lambda:  7.432486579840555e-05
#
# Poison Proportion:  7.97 %
#
# After Flipping, Unpoisoned
#  Validation MSE:  0.0037623749723120934
#  Test MSE: 0.0047619349297774605
#
# After Flipping & Poisoning:
#  Validation MSE:  0.00868911953716346
#  Test MSE: 0.011638771117738988
#
#
# *****************************
# **** Poison Count:  178  ****
# *****************************
# Iteration  0
# Objective Value:  0.015609920534307646  Change:  0.015609920534307646
# Validation MSE  0.013013129918150507
# Test MSE  0.016587673892458448
#
# Iteration  1
# Objective Value: 0.0052430522891614185  Difference:  -0.010366868245146228
# NO PROGRESS MADE!
#
# Iteration  2
# Objective Value: 0.005243050309622806  Difference:  -0.01036687022468484
# NO PROGRESS MADE!
#
# Iteration  3
# Objective Value: 0.005243050657035939  Difference:  -0.010366869877271707
# NO PROGRESS MADE!
#
# Iteration  4
# Objective Value: 0.005243050439094338  Difference:  -0.010366870095213308
# NO PROGRESS MADE!
#
# Iteration  5
# Objective Value: 0.005243047712886393  Difference:  -0.010366872821421253
# NO PROGRESS MADE!
#
# Poisoned classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True) ,
# Returned lambda:  7.432486579840555e-05
#
# Poison Proportion:  11.95 %
#
# After Flipping, Unpoisoned
#  Validation MSE:  0.0037623749723120934
#  Test MSE: 0.0047619349297774605
#
# After Flipping & Poisoning:
#  Validation MSE:  0.013013129918150507
#  Test MSE: 0.016587673892458448
#
#
# *****************************
# **** Poison Count:  249  ****
# *****************************
# Iteration  0
# Objective Value:  0.021030314348908577  Change:  0.021030314348908577
# Validation MSE  0.018201310476500455
# Test MSE  0.02226752762881301
#
# Iteration  1
# Objective Value: 0.005427898112772611  Difference:  -0.015602416236135966
# NO PROGRESS MADE!
#
# Iteration  2
# Objective Value: 0.005427925866928757  Difference:  -0.015602388481979819
# NO PROGRESS MADE!
#
# Iteration  3
# Objective Value: 0.005427949328593029  Difference:  -0.015602365020315548
# NO PROGRESS MADE!
#
# Iteration  4
# Objective Value: 0.005427969247698197  Difference:  -0.01560234510121038
# NO PROGRESS MADE!
#
# Iteration  5
# Objective Value: 0.005427986090924313  Difference:  -0.015602328257984265
# NO PROGRESS MADE!
#
# Poisoned classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True) ,
# Returned lambda:  7.432486579840555e-05
#
# Poison Proportion:  15.93 %
#
# After Flipping, Unpoisoned
#  Validation MSE:  0.0037623749723120934
#  Test MSE: 0.0047619349297774605
#
# After Flipping & Poisoning:
#  Validation MSE:  0.018201310476500455
#  Test MSE: 0.02226752762881301
#
#
# *****************************
# **** Poison Count:  328  ****
# *****************************
# Iteration  0
# Objective Value:  0.026814656666710988  Change:  0.026814656666710988
# Validation MSE  0.02384177694334573
# Test MSE  0.028476895601087775
#
# Iteration  1
# Objective Value: 0.005690871670627053  Difference:  -0.021123784996083934
# NO PROGRESS MADE!
#
# Iteration  2
# Objective Value: 0.005690895197959581  Difference:  -0.021123761468751407
# NO PROGRESS MADE!
#
# Iteration  3
# Objective Value: 0.005690915223805429  Difference:  -0.021123741442905557
# NO PROGRESS MADE!
#
# Iteration  4
# Objective Value: 0.005690932219287243  Difference:  -0.021123724447423744
# NO PROGRESS MADE!
#
# Iteration  5
# Objective Value: 0.005690946657120125  Difference:  -0.021123710009590863
# NO PROGRESS MADE!
#
# Poisoned classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True) ,
# Returned lambda:  7.432486579840555e-05
# Poison Proportion:  19.91 %. Max reached, terminate
#
# After Flipping, Unpoisoned
#  Validation MSE:  0.0037623749723120934
#  Test MSE: 0.0047619349297774605
#
# After Flipping & Poisoning:
#  Validation MSE:  0.02384177694334573
#  Test MSE: 0.028476895601087775

# %% [markdown]
# # B Flip & Elastic Network Poisoner

# %%
# flip the data
x_flip, y_flip = flip_data.flip_data.B_flip(poi_train_x,poi_train_y,poison_ct)

poiser = gd_poisoner.e_net_poisoner(poi_train_x, poi_train_y, poi_test_x, poi_test_y, poi_val_x, poi_val_y, eta, beta, sigma, epsilon)
classifier, lam = poiser.learn_model(np.concatenate((poi_train_x, x_flip), axis=0), poi_train_y + y_flip, None)
print("classifier: ", classifier)
err = poiser.compute_error(classifier,False,False)[0]
x_flip = np.matrix(x_flip)
y_flip = y_flip[:]
"""
Evaluate the poisoning attack with the poison rate of 4%, 8%, 12%, 16%, 20%
"""
for i in  range(5):
    # calculate the amt of data that should be poisoned in this iteration
    current_prop = 0.2*(i + 1)*total_prop
    sample_amt = int(train_ct*(current_prop/(1 - current_prop)))
    current_x_pois = x_flip[:sample_amt,:]
    current_y_pois = y_flip[:sample_amt]
    # poison data
    x_pois_result, y_pois_result = poiser.poison_data(current_x_pois, current_y_pois,stop1, stop2, stop3, decrease_rate)
    x_poised = np.concatenate((poi_train_x,x_pois_result),axis = 0)
    y_poised = poi_train_y + y_pois_result
    # train the model on poisoned data
    classifier_poised, lam = poiser.learn_model(x_poised,y_poised,None)
    print("Poisoned classifier: ", classifier_poised, ", \nReturned lambda: ", lam)
    classifier = poiser.init_classifier
    if i != 4:
        err_unpoised = poiser.compute_error(classifier,False,False)
        err = poiser.compute_error(classifier_poised,False,False)
        print("\nPoison Proportion: ", round(current_prop*100,2),"%")
    else:
        err_unpoised = poiser.compute_error(classifier,True,False)
        err = poiser.compute_error(classifier_poised,True,True)
        print("\nPoison Proportion: ", round(total_prop*100,2), "%. Max reached, terminate")
    print("\nAfter Flipping, Unpoisoned \n Validation MSE: ", err_unpoised[0], "\n Test MSE:", err_unpoised[1])
    print("\nAfter Flipping & Poisoning:\n Validation MSE: ", err[0], "\n Test MSE:", err[1])
# Out:
# classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True)
#
#
# *****************************
# **** Poison Count:  54  ****
# *****************************
# Iteration  0
# Objective Value:  0.005908969922432496  Change:  0.005908969922432496
# Validation MSE  0.004949610561139075
# Test MSE  0.005766158210774625
#
# Iteration  1
# Objective Value: 0.005535400934751858  Difference:  -0.00037356898768063813
# NO PROGRESS MADE!
#
# Iteration  2
# Objective Value: 0.005531770327957264  Difference:  -0.000377199594475232
# NO PROGRESS MADE!
#
# Iteration  3
# Objective Value: 0.005528674384710135  Difference:  -0.0003802955377223607
# NO PROGRESS MADE!
#
# Iteration  4
# Objective Value: 0.005526050022412966  Difference:  -0.00038291990001953005
# NO PROGRESS MADE!
#
# Iteration  5
# Objective Value: 0.005523810693661832  Difference:  -0.00038515922877066424
# NO PROGRESS MADE!
#
# Poisoned classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True) ,
# Returned lambda:  7.432486579840555e-05
#
# Poison Proportion:  3.98 %
#
# After Flipping, Unpoisoned
#  Validation MSE:  0.0037623749723120934
#  Test MSE: 0.0047619349297774605
#
# After Flipping & Poisoning:
#  Validation MSE:  0.004949610561139075
#  Test MSE: 0.005766158210774625
#
#
# *****************************
# **** Poison Count:  114  ****
# *****************************
# Iteration  0
# Objective Value:  0.008231977038818823  Change:  0.008231977038818823
# Validation MSE  0.007538497753232927
# Test MSE  0.008389767164496903
#
# Iteration  1
# Objective Value: 0.006163740042257236  Difference:  -0.002068236996561587
# NO PROGRESS MADE!
#
# Iteration  2
# Objective Value: 0.006159856274167514  Difference:  -0.0020721207646513086
# NO PROGRESS MADE!
#
# Iteration  3
# Objective Value: 0.006156560141053125  Difference:  -0.002075416897765698
# NO PROGRESS MADE!
#
# Iteration  4
# Objective Value: 0.00615375969664624  Difference:  -0.002078217342172583
# NO PROGRESS MADE!
#
# Iteration  5
# Objective Value: 0.0061513829620333  Difference:  -0.002080594076785523
# NO PROGRESS MADE!
#
# Poisoned classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True) ,
# Returned lambda:  7.432486579840555e-05
#
# Poison Proportion:  7.97 %
#
# After Flipping, Unpoisoned
#  Validation MSE:  0.0037623749723120934
#  Test MSE: 0.0047619349297774605
#
# After Flipping & Poisoning:
#  Validation MSE:  0.007538497753232927
#  Test MSE: 0.008389767164496903
#
#
# *****************************
# **** Poison Count:  178  ****
# *****************************
# Iteration  0
# Objective Value:  0.011510174290225194  Change:  0.011510174290225194
# Validation MSE  0.011107251183654146
# Test MSE  0.011739016402369828
#
# Iteration  1
# Objective Value: 0.007748110847445693  Difference:  -0.003762063442779501
# NO PROGRESS MADE!
#
# Iteration  2
# Objective Value: 0.007744566697616058  Difference:  -0.003765607592609136
# NO PROGRESS MADE!
#
# Iteration  3
# Objective Value: 0.007741554241082872  Difference:  -0.0037686200491423225
# NO PROGRESS MADE!
#
# Iteration  4
# Objective Value: 0.007738995292449199  Difference:  -0.0037711789977759955
# NO PROGRESS MADE!
#
# Iteration  5
# Objective Value: 0.007736821421654853  Difference:  -0.0037733528685703413
# NO PROGRESS MADE!
#
# Poisoned classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True) ,
# Returned lambda:  7.432486579840555e-05
#
# Poison Proportion:  11.95 %
#
# After Flipping, Unpoisoned
#  Validation MSE:  0.0037623749723120934
#  Test MSE: 0.0047619349297774605
#
# After Flipping & Poisoning:
#  Validation MSE:  0.011107251183654146
#  Test MSE: 0.011739016402369828
#
#
# *****************************
# **** Poison Count:  249  ****
# *****************************
# Iteration  0
# Objective Value:  0.015936369693482947  Change:  0.015936369693482947
# Validation MSE  0.015260818901562816
# Test MSE  0.016195936587597222
#
# Iteration  1
# Objective Value: 0.009283917222160768  Difference:  -0.006652452471322179
# NO PROGRESS MADE!
#
# Iteration  2
# Objective Value: 0.0092813883552469  Difference:  -0.006654981338236048
# NO PROGRESS MADE!
#
# Iteration  3
# Objective Value: 0.009279221706325018  Difference:  -0.006657147987157929
# NO PROGRESS MADE!
#
# Iteration  4
# Objective Value: 0.00927739368736052  Difference:  -0.006658976006122428
# NO PROGRESS MADE!
#
# Iteration  5
# Objective Value: 0.00927586650054956  Difference:  -0.006660503192933386
# NO PROGRESS MADE!
#
# Poisoned classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True) ,
# Returned lambda:  7.432486579840555e-05
#
# Poison Proportion:  15.93 %
#
# After Flipping, Unpoisoned
#  Validation MSE:  0.0037623749723120934
#  Test MSE: 0.0047619349297774605
#
# After Flipping & Poisoning:
#  Validation MSE:  0.015260818901562816
#  Test MSE: 0.016195936587597222
#
#
# *****************************
# **** Poison Count:  328  ****
# *****************************
# Iteration  0
# Objective Value:  0.021316012459101783  Change:  0.021316012459101783
# Validation MSE  0.020377883603828625
# Test MSE  0.022062398616725654
#
# Iteration  1
# Objective Value: 0.013057753113614363  Difference:  -0.00825825934548742
# NO PROGRESS MADE!
#
# Iteration  2
# Objective Value: 0.01305582937807122  Difference:  -0.008260183081030563
# NO PROGRESS MADE!
#
# Iteration  3
# Objective Value: 0.013054194177941117  Difference:  -0.008261818281160667
# NO PROGRESS MADE!
#
# Iteration  4
# Objective Value: 0.013052807358851155  Difference:  -0.008263205100250628
# NO PROGRESS MADE!
#
# Iteration  5
# Objective Value: 0.013051625651122665  Difference:  -0.008264386807979118
# NO PROGRESS MADE!
#
# Poisoned classifier:  ElasticNet(alpha=7.432486579840555e-05, max_iter=10000, warm_start=True) ,
# Returned lambda:  7.432486579840555e-05
# Poison Proportion:  19.91 %. Max reached, terminate
#
# After Flipping, Unpoisoned
#  Validation MSE:  0.0037623749723120934
#  Test MSE: 0.0047619349297774605
#
# After Flipping & Poisoning:
#  Validation MSE:  0.020377883603828625
#  Test MSE: 0.022062398616725654
